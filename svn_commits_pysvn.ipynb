# %%
#coding=utf-8
import re
import pysvn
import datetime
import time
import pandas as pd


from sqlalchemy import create_engine
from sqlalchemy import types as sqltype
from config.database import HOST, PORT, USER, PASSWORD, DATABASE

import psycopg2

import gc

# %%
#coding=utf-8
work_dir = '/mnt/data0/proj_osgeo/data_svn/svn_repos/gvsig-desktop/gvsig-desktop'
client = pysvn.Client()
entry = client.info(work_dir)

print ('SVN路径:',entry.url)
print ('最新版本:',entry.commit_revision.number)
print ('提交人员:',entry.commit_author)
print ('更新日期:', datetime.datetime.fromtimestamp(entry.commit_time))



#列出最近更新5版本的文件列表
entries_list = client.log(work_dir, discover_changed_paths=True)
list=[]
for i in range(5):
    message =re.findall(r"\d+",str(entries_list[i].revision)),entries_list[i].message
    list.append(message)
#b= json.dumps(list)
#b = json.dumps(list,encoding="UTF-8",ensure_ascii=False)
#b = b.replace('\"', '')
print(list)
# Out:
# SVN路径: http://devel.gvsig.org/svn/gvsig-desktop
# 最新版本: 45945
# 提交人员: fdiaz
# 更新日期: 2021-10-11 02:02:43.051425
# [(['45952'], 'fix JDynformFieldExpression'), (['45951'], 'fix compile empty expression'), (['45950'], 'fix compile empty expression'), (['45949'], 'Fix ST_boundary description'), (['45948'], 'add getCharset method to RandomAccessFilereader')]

# %%
def escape(s):
    return (s).replace('\'','\'\'').replace("\\","\\\\")

#寻找svn账户的邮箱
def save_aliase(entry, urladd):
    try:
        db = psycopg2.connect(
            host=HOST,
            port=PORT,
            user=USER,
            password=PASSWORD,
            database=DATABASE)
            #charset='utf8')
        cursor = db.cursor()
    except Exception as e:
        print("Database connect error:%s" % e)
    
    try:
        svn_id = entry.author
    except BaseException as err:
        #print("Adding Aliase Error:",err)
        svn_id = "noauthor"
    if '@' in svn_id:
        svn_mail = svn_id
    else:
        svn_mail = svn_id+'@'+urladd
    source = "SVN"
    

    sql_aliase = """INSERT INTO aliase(aliase_id, mailaddress, source)
                                    values('%s', '%s', '%s')""" % (
    svn_id, svn_mail, source)

    try:
        db.commit()
        cursor.execute(sql_aliase)
        db.commit()
    except Exception as err:
        sql_aliase = """UPDATE aliase SET mailaddress ='%s', source='%s' WHERE aliase_id='%s'"""% (
                        svn_mail, source, svn_id)
            
        db.commit()
        cursor.execute(sql_aliase)
        db.commit()
        #print(err)

    return svn_id

def save_one_filelog(entry, proj, filelog):
    try:
        db = psycopg2.connect(
            host=HOST,
            port=PORT,
            user=USER,
            password=PASSWORD,
            database=DATABASE)
            #charset='utf8')
        cursor = db.cursor()
    except Exception as e:
        print("Database connect error:%s" % e)
    try:
        svn_commiter_id = entry.author
    except BaseException as err:
        #print("Aliase Error:",err)
        svn_commiter_id = "noauthor"

    rev_number = str(entry.revision.number)

    id_commit = proj+'#'+rev_number+'#'+svn_commiter_id
    id_filelog = id_commit+'#'+filelog.path
    source = "SVN"

    if filelog.copyfrom_path!= None :
        fadded = filelog.copyfrom_revision.number
        fremoved = filelog.copyfrom_path
    else:
        fadded = "None"
        fremoved = "None"

    sql = """INSERT INTO filelog(filelog_id, commit_id, action, file_name, added, removed)
            values('%s', '%s', '%s','%s', '%s', '%s')""" % (escape(id_filelog), id_commit, filelog.action, escape(filelog.path), fadded, escape(fremoved))

    try:
        db.commit()
        cursor.execute(sql)
        db.commit()
        #print("%s : Insert successfully" % entry['id'])
    except Exception as e:
        try:  # 插入失败表示数据库存在此entry，转为update更新
            db.commit()
            #print("Exception: %s" % e)
            sql_update = """UPDATE filelog SET
              commit_id='%s', action='%s', file_name='%s', added='%s', removed='%s'
             WHERE filelog_id='%s'""" % (id_commit, filelog.action, escape(filelog.path), fadded, escape(fremoved), escape(id_filelog))
            cursor.execute(sql_update)
            db.commit()
            #print("%s : Update successfully" % entry['id'])
        except Exception as err:
            print("Save filelog Exception: %s" % err)
            print("update error:%s" % err)
            db.rollback()

def save_one_svncommit(entry, proj):
    try:
        db = psycopg2.connect(
            host=HOST,
            port=PORT,
            user=USER,
            password=PASSWORD,
            database=DATABASE)
            #charset='utf8')
        cursor = db.cursor()
    except Exception as e:
        print("Database connect error:%s" % e)
    try:
        svn_commiter_id = entry.author
    except BaseException as err:
        #print("Aliase Error:",err)
        svn_commiter_id = "noauthor"
    
    rev_number = str(entry.revision.number)
    id_commit = proj+'#'+rev_number+'#'+svn_commiter_id
    source = "SVN"
    
    time_format = "%Y-%m-%d %H:%M:%S"
    struct_time = datetime.datetime.fromtimestamp(entry.date)
    t_commit = datetime.datetime.strftime(struct_time, time_format)
    

    sql = """INSERT INTO commit(commit_id, proj_id, commiter_aliase_id, commit_message, commit_timestamp, commit_sha, commit_parents, commit_refs)
                                        values('%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s')""" % (
        id_commit, proj, svn_commiter_id, escape(entry.message), t_commit, rev_number, entry.revision.kind, source)

    try:
        db.commit()
        cursor.execute(sql)
        db.commit()
        #print("%s : Insert successfully" % entry['id'])
    except Exception as e:
        try:  # 插入失败表示数据库存在此entry，转为update更新
            db.commit()
            #print("Exception: %s" % e)
            sql_update = """UPDATE commit SET
             proj_id='%s', commiter_aliase_id='%s', commit_message='%s', commit_timestamp='%s', commit_sha='%s', commit_parents='%s', commit_refs='%s'
             WHERE commit_id='%s'""" % (proj, entry.author, escape(entry.message), t_commit, rev_number, entry.revision.kind, source, id_commit)
            cursor.execute(sql_update)
            db.commit()
            #print("%s : Update successfully" % entry['id'])
        except Exception as err:
            print("Save commit Exception: %s" % err)
            print("update error:%s" % err)
            db.rollback()

# %%
df = pd.read_csv("../svn_repository.csv")
svn_source_url = df["Repos"].values

# %%
#coding=utf-8

for work_dir in svn_source_url:
    #work_dir = '/mnt/data0/proj_osgeo/data_svn/svn_repos/gvsig-desktop/gvsig-desktop'
    #proj = gvsig-desktop
    proj = str(df.loc[df["Repos"] == work_dir]["Projects"].values[0]).lower()
    urladd = work_dir.split("//")[1].split('/')[0]
    print(proj, urladd)
    client = pysvn.Client()

    try:
        local_dir = str(df.loc[df["Repos"] == work_dir]["Local"].values[0])
        entry = client.info(local_dir)
        print ('SVN路径:',entry.url)
        print ('最新版本:',entry.commit_revision.number)
        print ('提交人员:',entry.commit_author)
        print ('更新日期:', datetime.datetime.fromtimestamp(entry.commit_time))

    except BaseException as err:
        print("No local!")
        local_dir = work_dir
        print("Pull from remote:" + work_dir)
        

    


    #列出最近更新5版本的文件列表
    entries_list = client.log(local_dir, discover_changed_paths=True)
    print("Successfully Pulled all logs.")
    for entry in entries_list:
        try:
            #print(re.findall(r"\d+",str(entry.revision)),entry.message)
            save_aliase(entry, urladd)
            save_one_svncommit(entry, proj)
            for filelog in entry.changed_paths:
                save_one_filelog(entry, proj, filelog)
        except BaseException as err:
            print(err)
        finally:
            gc.collect()
# Out:
# gvsig-desktop devel.gvsig.org
# SVN路径: http://devel.gvsig.org/svn/gvsig-desktop
# 最新版本: 45945
# 提交人员: fdiaz
# 更新日期: 2021-10-11 02:02:43.051425
# Successfully Pulled all logs.
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# opticks svn.code.sf.net
# SVN路径: http://svn.code.sf.net/p/opticks/code
# 最新版本: 18810
# 提交人员: retrev
# 更新日期: 2015-10-06 11:24:52.424884
# Successfully Pulled all logs.
# mapguide svn.osgeo.org
# SVN路径: https://svn.osgeo.org/mapguide
# 最新版本: -1
# 提交人员: None
# 更新日期: 1969-12-31 16:00:00
# Successfully Pulled all logs.
# zoo svn.zoo-project.org
# SVN路径: http://svn.zoo-project.org/svn
# 最新版本: 986
# 提交人员: djay
# 更新日期: 2021-03-09 07:50:02.591284
# Successfully Pulled all logs.
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# fdo svn.osgeo.org
# No local!
# Pull from remote:https://svn.osgeo.org/fdo/
# Successfully Pulled all logs.
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.dbf', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.dbf', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...y/gdal/Providers/SDF/TestData/~`!@#$%^&()_-+}{[]',.sdf', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...y/gdal/Providers/SDF/TestData/~`!@#$%^&()_-+}{[]',.sdf', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: .../NBenguela.2004357.aqua.250m  (.!,@#$%^()_+=-`~[]').jgw', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: .../NBenguela.2004357.aqua.250m  (.!,@#$%^()_+=-`~[]').jgw', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: .../NBenguela.2004357.aqua.250m  (.!,@#$%^()_+=-`~[]').jpg', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: .../NBenguela.2004357.aqua.250m  (.!,@#$%^()_+=-`~[]').jpg', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.sbn', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.sbn', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.sbx', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.sbx', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...gdal/Providers/SDF/TestData/~`!@#$%^&()_-+=}{[];',.sdf', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...gdal/Providers/SDF/TestData/~`!@#$%^&()_-+=}{[];',.sdf', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.shp', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.shp', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.shx', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.shx', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.sbn', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.sbn', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.sbx', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.sbx', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.shp', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.shp', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.shx', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.shx', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.dbf', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.dbf', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').png', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').png', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...s/GDAL/TestData/PNG/COTcvdm.U (.!,@#$%^()_+=-`~[]').png', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...s/GDAL/TestData/PNG/COTcvdm.U (.!,@#$%^()_+=-`~[]').png', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...s/GDAL/TestData/PNG/COTcvdm.U (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...s/GDAL/TestData/PNG/COTcvdm.U (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').png', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...ders/GDAL/TestData/PNG/CM13ct (.!,@#$%^()_+=-`~[]').png', ad...
#                                                              ^
#
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# Save filelog Exception: syntax error at or near "."
# LINE 2: .../trunk/Providers/SDF/TestData/~`!@#$%^&()_-+}{[]',.sdf', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: .../trunk/Providers/SDF/TestData/~`!@#$%^&()_-+}{[]',.sdf', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...runk/Providers/SDF/TestData/~`!@#$%^&()_-+=}{[];',.sdf', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...runk/Providers/SDF/TestData/~`!@#$%^&()_-+=}{[];',.sdf', add...
#                                                              ^
#
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.sbx', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.sbx', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.sbn', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.sbn', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.shx', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.shx', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.shp', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.shp', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.dbf', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.dbf', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.sbx', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.sbx', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.sbn', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.sbn', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.shx', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...viders/SHP/TestData/Ontario/~`!@#$%^&()_-+=}{[];',.shx', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.shp', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.shp', add...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.dbf', add...
#                                                              ^
#
# update error:syntax error at or near "."
# LINE 2: ...roviders/SHP/TestData/Ontario/~`!@#$%^&()_-+}{[]',.dbf', add...
#                                                              ^
#
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...s/GDAL/TestData/PNG/COTcvdm.U (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...s/GDAL/TestData/PNG/COTcvdm.U (.!,@#$%^()_+=-`~[]').pgw', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: .../NBenguela.2004357.aqua.250m  (.!,@#$%^()_+=-`~[]').jgw', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: .../NBenguela.2004357.aqua.250m  (.!,@#$%^()_+=-`~[]').jgw', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: ...s/GDAL/TestData/PNG/COTcvdm.U (.!,@#$%^()_+=-`~[]').png', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: ...s/GDAL/TestData/PNG/COTcvdm.U (.!,@#$%^()_+=-`~[]').png', ad...
#                                                              ^
#
# Save filelog Exception: syntax error at or near ")"
# LINE 2: .../NBenguela.2004357.aqua.250m  (.!,@#$%^()_+=-`~[]').jpg', ad...
#                                                              ^
#
# update error:syntax error at or near ")"
# LINE 2: .../NBenguela.2004357.aqua.250m  (.!,@#$%^()_+=-`~[]').jpg', ad...
#                                                              ^
#
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# ossim svn.osgeo.org
# No local!
# Pull from remote:https://svn.osgeo.org/ossim/
# Successfully Pulled all logs.
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# metacrs svn.osgeo.org
# No local!
# Pull from remote:http://svn.osgeo.org/metacrs
# Successfully Pulled all logs.
# Save filelog Exception: syntax error at or near "s"
# LINE 2: ..., file_name='/csmap/trunk/Preliminary CS-MAP User's Guide.pd...
#                                                              ^
#
# update error:syntax error at or near "s"
# LINE 2: ..., file_name='/csmap/trunk/Preliminary CS-MAP User's Guide.pd...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "s"
# LINE 2: ...csmap/trunk/Documentation/Preliminary CS-MAP User's Guide.pd...
#                                                              ^
#
# update error:syntax error at or near "s"
# LINE 2: ...csmap/trunk/Documentation/Preliminary CS-MAP User's Guide.pd...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "s"
# LINE 2: ..., file_name='/csmap/trunk/Preliminary CS-MAP User's Guide.pd...
#                                                              ^
#
# update error:syntax error at or near "s"
# LINE 2: ..., file_name='/csmap/trunk/Preliminary CS-MAP User's Guide.pd...
#                                                              ^
#
# Save filelog Exception: syntax error at or near "s"
# LINE 2: ...nk/CsMapDev/Documentation/Preliminary CS-MAP User's Guide.pd...
#                                                              ^
#
# update error:syntax error at or near "s"
# LINE 2: ...nk/CsMapDev/Documentation/Preliminary CS-MAP User's Guide.pd...
#                                                              ^
#
# fdo svn.osgeo.org
# SVN路径: https://svn.osgeo.org/fdo32x
# 最新版本: 121
# 提交人员: None
# 更新日期: 2007-01-25 16:29:19.347919
# Successfully Pulled all logs.
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# fdo svn.osgeo.org
# SVN路径: https://svn.osgeo.org/fdoarcsde
# 最新版本: 178
# 提交人员: romicadascalescu
# 更新日期: 2008-04-02 11:10:52.013252
# Successfully Pulled all logs.
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# fdo svn.osgeo.org
# SVN路径: https://svn.osgeo.org/fdocore
# 最新版本: 880
# 提交人员: brentrobinson
# 更新日期: 2008-06-10 10:24:05.809915
# Successfully Pulled all logs.
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# PysvnLog instance has no attribute 'author'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-48294f7db211> in <module>
#      39             print(err)
#      40         finally:
# ---> 41             gc.collect()
#      42
#
# KeyboardInterrupt:

# %%
time_format = "%Y-%m-%d %H:%M:%S"
t_commit = time.strftime(time_format, 1634496200.270716)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3ee7a020d072> in <module>
#       1 time_format = "%Y-%m-%d %H:%M:%S"
# ----> 2 t_commit = time.strftime(time_format, 1634496200.270716)
#
# TypeError: Tuple or struct_time argument required
